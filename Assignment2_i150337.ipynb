               ['17','2b','04','7e','ba','77','d6','26','e1','69','14','63','55','21','0c','7d']]
#########function for generating round constant for particular round##########################################
def generate_rcon(rnd):
    rcon = 0x8d
    for i in range(0, rnd):
        rcon = ((rcon << 1) ^ (0x11b & - (rcon >> 7))) & 0xff
    return rcon
#########function to rotate an array left by n################################################################
def rotate_left(lst, n):
    return lst[n:] + lst[:n]
#########function to rotate an array right by n################################################################
def rotate_right(lst, n):
    ll = len(lst)
    return lst[(ll-n):] + lst[:(ll-n)]
#########function to generate a 128 bit key ##################################################################
def generate_Key(customkey = ""):
    if customkey != "":
        if len(customkey) == 16:
            return customkey
        else:
            print("custom key is of wrong length using random key")
            lettersAndDigits = string.ascii_letters + string.digits
            key = ''.join(random.choice(lettersAndDigits) for i in range(16))
            return key
    else:
        lettersAndDigits = string.ascii_letters + string.digits
        key = ''.join(random.choice(lettersAndDigits) for i in range(16))
        return key
#########function used in key expansion on w3###################################################################
def g(w3,rnd):
######left rotate w3 once###################        
    w3 = rotate_left(w3,1)
######substitue with s-box##################
    for i in range(0,4,1):
        if len(w3[i]) ==1:
            temp=w3[i]
            w3[i]='0' + temp
    for i in range(0,4,1):
        w3[i] =  Sbox[int(w3[i][0],16)] [int(w3[i][1],16)]
######adding round constant#################
    w3[0] = hex(int(w3[0],16)^generate_rcon(rnd))[2:]
######returning w3##########################    
    return w3
########function for generating round keys#########################################################    
def gererate_round_keys(key):
    round_keys=[]    
    key_matrix = [[0] * 4 for i in range(4)]
    ind=0
    for i in range(0,4,1):
        for j in range(0,4,1):
            temp=ord(key[ind])
            temp=hex(temp)
            key_matrix[j][i] = temp[2] + temp[3]
            ind=ind+1
    #####generating w0-w3 from key matrix ##############
    w0=[]
    w1=[]
    w2=[]
    w3=[]
    for i in range(0,4,1):
        w0.append(key_matrix[i][0])
        w1.append(key_matrix[i][1])
        w2.append(key_matrix[i][2])
        w3.append(key_matrix[i][3]) 
    rk = w0+w1+w2+w3
    round_keys.append(rk)
    ######generating all other round keys ##############
    for i in range(10):
        w4=[]
        w5=[]
        w6=[]
        w7=[]
        gw3 = g(w3,i+1)
        for i in range(0,4,1):
            w4.append(hex(int(gw3[i],16) ^ int(w0[i],16))[2:])
            w5.append(hex(int(w4[i],16) ^ int(w1[i],16))[2:])
            w6.append(hex(int(w5[i],16) ^ int(w2[i],16))[2:])
            w7.append(hex(int(w6[i],16) ^ int(w3[i],16))[2:])
        w0 = w4
        w1 = w5
        w2 = w6
        w3 = w7
        rk = w0+w1+w2+w3
        round_keys.append(rk)
    return round_keys
########convert key to matrix###############################################################################
def key_to_matrix(round_key):
    key_matrix = [[0] * 4 for i in range(4)]
    ind=0
    for i in range(0,4,1):
        for j in range(0,4,1):
            key_matrix[j][i] = round_key[ind]
            ind=ind+1
    return key_matrix  
########Substitue bytes in state matrix using S-box#########################################################
def sub_bytes(state_matrix):
    for i in range(4):
        for j in range(4):
            if len(state_matrix[i][j]) ==1:
                temp=state_matrix[i][j]
                state_matrix[i][j]='0' + temp
    for i in range(4):
        for j in range(4):
            state_matrix[i][j] = Sbox[int(state_matrix[i][j][0],16)][int(state_matrix[i][j][1],16)]
    return state_matrix
########Inverse Substitue bytes in state matrix using S-box#########################################################
def inv_sub_bytes(state_matrix):
    for i in range(4):
        for j in range(4):
            if len(state_matrix[i][j]) ==1:
                temp=state_matrix[i][j]
                state_matrix[i][j]='0' + temp
    for i in range(4):
        for j in range(4):
            state_matrix[i][j] = S_Inverse_box[int(state_matrix[i][j][0],16)][int(state_matrix[i][j][1],16)]
    return state_matrix
########shift rows of state matrix##########################################################################
def shift_rows(state_matrix):
    for i in range(4):
        state_matrix[i] =rotate_left(state_matrix[i],i)
    return state_matrix
########inverse shift rows of state matrix##########################################################################
def inv_shift_rows(state_matrix):
    for i in range(4):
        state_matrix[i] =rotate_right(state_matrix[i],i)
    return state_matrix
########functions for mixing columns########################################################################
def gfMultiply(cfm,smv):
    r = 0
    if cfm=='01':
        return int(smv,16)
    elif cfm=='02':
        r = (int(smv,16)<<1)
        if r>0xFF:
            r = r^0x11b
    else:
        r = int(smv,16)<<1
        if r>0xFF:
            r = r^0x11b
        r = r^int(smv,16)
    return r
def MixColumns(state_matrix):
    result_matrix = [[0] * 4 for i in range(4)]
    A = [['02','03','01','01'],
         ['01','02','03','01'],
         ['01','01','02','03'],
         ['03','01','01','02']]
    ind = 0
    for i in range(4):
        for j in range(4):
            temp=0
            for k in range(4):
                    temp = gfMultiply(A[i][k],state_matrix[k][j])
                    result_matrix[i][j] ^= temp
                    ind += 1
    for i in range(4):
        for j in range(4):
            state_matrix[i][j] = hex(result_matrix[i][j])[2:]
    return state_matrix
########functions for inverse mixing columns########################################################################
def mul_by_02(num):
    if int(num,16) < 128:
        res = (int(num,16) << 1)
    else:
        res = (int(num,16) << 1) ^ 0x1b

    return hex(res % 256)[2:]
def inv_gfMultiply(cfm,num):
    
    if cfm == '09':
        return int(mul_by_02(mul_by_02(mul_by_02(num))),16) ^ int(num,16)
    elif cfm == '0b':
        return int(mul_by_02(mul_by_02(mul_by_02(num))),16) ^ int(mul_by_02(num),16) ^ int(num,16)
    elif cfm == '0d':
        return int(mul_by_02(mul_by_02(mul_by_02(num))),16) ^ int(mul_by_02(mul_by_02(num)),16) ^ int(num,16)
    elif cfm == "0e":
        return int(mul_by_02(mul_by_02(mul_by_02(num))),16) ^ int(mul_by_02(mul_by_02(num)),16) ^ int(mul_by_02(num),16)

def inv_MixColumns(state_matrix):
    result_matrix = [[0] * 4 for i in range(4)]
    inv_cm = [['0e','0b','0d','09'],
              ['09','0e','0b','0d'],
              ['0d','09','0e','0b'],
              ['0b','0d','09','0e']]
    for i in range(4):
        for j in range(4):
            temp=0
            for k in range(4):
                    temp = inv_gfMultiply(inv_cm[i][k],state_matrix[k][j])
                    result_matrix[i][j] ^= temp
    for i in range(4):
        for j in range(4):
            state_matrix[i][j] = hex(result_matrix[i][j])[2:]
    return state_matrix
########function for encryption with all round keys#########################################################    
def encrypt(Plain_text,round_keys):
    state_matrix = [[0] * 4 for i in range(4)]
    text_matrix = [[0] * 4 for i in range(4)]
########converting plain text to matrix and hex########  
    ind=0
    for i in range(0,4,1):
        for j in range(0,4,1):
            temp=ord(Plain_text[ind])
            temp=hex(temp)
            text_matrix[j][i] = temp[2] + temp[3]
            ind=ind+1
########taking round 0 key and performing key whitening########
    key_matrix = key_to_matrix(round_keys[0])
    for i in range(4):
        for j in range(4):
            state_matrix[i][j] = hex(int(text_matrix[i][j],16) ^ int(key_matrix[i][j],16))[2:]
    print(state_matrix, " key whitening ")
########performing round 1-9 encryption#######
    for rnd in range(9):
        state_matrix = sub_bytes(state_matrix)
        print(state_matrix, " sub bytes round: ",rnd+1)
        state_matrix = shift_rows(state_matrix)
        print(state_matrix," shift rows round: ",rnd+1)
        state_matrix = MixColumns(state_matrix)
        print(state_matrix," mix cols round: ",rnd+1)
        key_matrix = key_to_matrix(round_keys[rnd+1])
        for i in range(4):
            for j in range(4):
                state_matrix[i][j] = hex(int(state_matrix[i][j],16) ^ int(key_matrix[i][j],16))[2:]
        print(state_matrix," encrpted round: ",rnd+1)
########performing round 10 encryption without mixing columns#######
    state_matrix = sub_bytes(state_matrix)
    state_matrix = shift_rows(state_matrix)
    key_matrix = key_to_matrix(round_keys[10])
    for i in range(0,4,1):
        for j in range(0,4,1):
            state_matrix[i][j] = hex(int(state_matrix[i][j],16) ^ int(key_matrix[i][j],16))[2:]
    print(state_matrix," encrypted round: 10")
#######converting state matrix to list to return cipher text#######
    encrypted_text =[]
    for i in range(4):
        for j in range(4):
            encrypted_text.append(state_matrix[j][i])
    return(encrypted_text)
########function for decryption with all round keys#########################################################    
def decrypt(cipher_text,round_keys):
    state_matrix = [[0] * 4 for i in range(4)]
    text_matrix = [[0] * 4 for i in range(4)]
########converting cipher text to matrix and hex######## 
    ind = 0
    for i in range(0,4,1):
        for j in range(0,4,1):
            text_matrix[j][i] = cipher_text[ind]  
            ind = ind+1
    print(text_matrix," cipher matrix ")
########taking round 10 key and performing key whitening########
    key_matrix = key_to_matrix(round_keys[10])
    for i in range(4):
        for j in range(4):
            state_matrix[i][j] = hex(int(text_matrix[i][j],16) ^ int(key_matrix[i][j],16))[2:]
    print(state_matrix, " key whitening inverse ")
########performing round 9-1 decryption#######
    for rnd in range(9):
        state_matrix = inv_shift_rows(state_matrix)
        print(state_matrix," I_shift rows round:",9-rnd)
        state_matrix = inv_sub_bytes(state_matrix)
        print(state_matrix, " I_sub bytes round:",9-rnd)
        key_matrix = key_to_matrix(round_keys[9-rnd])
        for i in range(4):
            for j in range(4):
                state_matrix[i][j] = hex(int(state_matrix[i][j],16) ^ int(key_matrix[i][j],16))[2:]
        print(state_matrix," decrpted round: ",9-rnd)
        state_matrix = inv_MixColumns(state_matrix)
        print(state_matrix," I_mix cols round: ",9-rnd)
########performing round 10 encryption without inverse mixing columns#######
    state_matrix = inv_shift_rows(state_matrix)
    print(state_matrix," I_shift rows round:",0)
    state_matrix = inv_sub_bytes(state_matrix)
    print(state_matrix, " I_sub bytes round:",0)
    key_matrix = key_to_matrix(round_keys[0])
    for i in range(0,4,1):
        for j in range(0,4,1):
            state_matrix[i][j] = hex(int(state_matrix[i][j],16) ^ int(key_matrix[i][j],16))[2:]
    print(state_matrix," decrypted round: 0")
#######converting state matrix to list to return decrypted text#######
    decrypted_text =[]
    for i in range(4):
        for j in range(4):
            decrypted_text.append(state_matrix[j][i])
    return(decrypted_text)

# %%
key = generate_Key("Thats my Kung Fu")
print("key being used: ",key)
round_keys = gererate_round_keys(key)
for i in range(len(round_keys)):
    print("round key for round : ",i,round_keys[i])
# Out:
# key being used:  Thats my Kung Fu
# round key for round :  0 ['54', '68', '61', '74', '73', '20', '6d', '79', '20', '4b', '75', '6e', '67', '20', '46', '75']
# round key for round :  1 ['e2', '32', 'fc', 'f1', '91', '12', '91', '88', 'b1', '59', 'e4', 'e6', 'd6', '79', 'a2', '93']
# round key for round :  2 ['56', '8', '20', '7', 'c7', '1a', 'b1', '8f', '76', '43', '55', '69', 'a0', '3a', 'f7', 'fa']
# round key for round :  3 ['d2', '60', 'd', 'e7', '15', '7a', 'bc', '68', '63', '39', 'e9', '1', 'c3', '3', '1e', 'fb']
# round key for round :  4 ['a1', '12', '2', 'c9', 'b4', '68', 'be', 'a1', 'd7', '51', '57', 'a0', '14', '52', '49', '5b']
# round key for round :  5 ['b1', '29', '3b', '33', '5', '41', '85', '92', 'd2', '10', 'd2', '32', 'c6', '42', '9b', '69']
# round key for round :  6 ['bd', '3d', 'c2', '87', 'b8', '7c', '47', '15', '6a', '6c', '95', '27', 'ac', '2e', 'e', '4e']
# round key for round :  7 ['cc', '96', 'ed', '16', '74', 'ea', 'aa', '3', '1e', '86', '3f', '24', 'b2', 'a8', '31', '6a']
# round key for round :  8 ['8e', '51', 'ef', '21', 'fa', 'bb', '45', '22', 'e4', '3d', '7a', '6', '56', '95', '4b', '6c']
# round key for round :  9 ['bf', 'e2', 'bf', '90', '45', '59', 'fa', 'b2', 'a1', '64', '80', 'b4', 'f7', 'f1', 'cb', 'd8']
# round key for round :  10 ['28', 'fd', 'de', 'f8', '6d', 'a4', '24', '4a', 'cc', 'c0', 'a4', 'fe', '3b', '31', '6f', '26']

# %%
Plain_text = "Two One Nine Two"
cipher_text = encrypt(Plain_text,round_keys)
print("cipher text after all 10 rounds: \n",cipher_text)
# Out:
# [['0', '3c', '6e', '47'], ['1f', '4e', '22', '74'], ['e', '8', '1b', '31'], ['54', '59', 'b', '1a']]  key whitening
# [['63', 'eb', '9f', 'a0'], ['c0', '2f', '93', '92'], ['ab', '30', 'af', 'c7'], ['20', 'cb', '2b', 'a2']]  sub bytes round:  1
# [['63', 'eb', '9f', 'a0'], ['2f', '93', '92', 'c0'], ['af', 'c7', 'ab', '30'], ['a2', '20', 'cb', '2b']]  shift rows round:  1
# [['ba', '84', 'e8', '1b'], ['75', 'a4', '8d', '40'], ['f4', '8d', '6', '7d'], ['7a', '32', 'e', '5d']]  mix cols round:  1
# [['a9', '37', 'aa', 'f2'], ['ae', 'd8', 'c', '21'], ['e7', '6c', 'b1', '9c'], ['f0', 'fd', '67', '3b']]  mix cols round:  6
# [['14', '8f', 'c0', '5e'], ['93', 'a4', '60', 'f'], ['25', '2b', '24', '92'], ['77', 'e8', '40', '75']]  encrpted round:  6
# [['fa', '73', 'ba', '58'], ['dc', '49', 'd0', '76'], ['3f', 'f1', '36', '4f'], ['f5', '9b', '09', '9d']]  sub bytes round:  7
# [['fa', '73', 'ba', '58'], ['49', 'd0', '76', 'dc'], ['36', '4f', '3f', 'f1'], ['9d', 'f5', '9b', '09']]  shift rows round:  7
# [['9f', '37', '51', '37'], ['af', 'ec', '8c', 'fa'], ['63', '39', '4', '66'], ['4b', 'fb', 'b1', 'd7']]  mix cols round:  7
# [['53', '43', '4f', '85'], ['39', '6', 'a', '52'], ['8e', '93', '3b', '57'], ['5d', 'f8', '95', 'bd']]  encrpted round:  7
# [['ed', '1a', '84', '97'], ['12', '6f', '67', '00'], ['19', 'dc', 'e2', '5b'], ['4c', '41', '2a', '7a']]  sub bytes round:  8
# [['ed', '1a', '84', '97'], ['6f', '67', '00', '12'], ['e2', '5b', '19', 'dc'], ['7a', '4c', '41', '2a']]  shift rows round:  8
# [['e8', '8a', '4b', 'f5'], ['74', '75', 'ee', 'e6'], ['d3', '1f', '75', '58'], ['55', '8a', 'c', '38']]  mix cols round:  8
# [['66', '70', 'af', 'a3'], ['25', 'ce', 'd3', '73'], ['3c', '5a', 'f', '13'], ['74', 'a8', 'a', '54']]  encrpted round:  8
# [['33', '51', '79', '0a'], ['3f', '8b', '66', '8f'], ['eb', 'be', '76', '7d'], ['92', 'c2', '67', '20']]  sub bytes round:  9
# [['33', '51', '79', '0a'], ['8b', '66', '8f', '3f'], ['76', '7d', 'eb', 'be'], ['20', '92', 'c2', '67']]  shift rows round:  9
# [['b6', 'e7', '51', '8c'], ['84', '88', '98', 'ca'], ['34', '60', '66', 'fb'], ['e8', 'd7', '70', '51']]  mix cols round:  9
# [['9', 'a2', 'f0', '7b'], ['66', 'd1', 'fc', '3b'], ['8b', '9a', 'e6', '30'], ['78', '65', 'c4', '89']]  encrpted round:  9
# [['29', '57', '40', '1a'], ['c3', '14', '22', '2'], ['50', '20', '99', 'd7'], ['5f', 'f6', 'b3', '3a']]  encrypted round: 10
# cipher text after all 10 rounds:
#  ['29', 'c3', '50', '5f', '57', '14', '20', 'f6', '40', '22', '99', 'b3', '1a', '2', 'd7', '3a']

# %%
decrypted_text = decrypt(cipher_text,round_keys)
ch=[]
for i in range(len(decrypted_text)):
    ch.append(chr(int(decrypted_text[i],16)))
print(ch)
# Out:
# [['29', '57', '40', '1a'], ['c3', '14', '22', '2'], ['50', '20', '99', 'd7'], ['5f', 'f6', 'b3', '3a']]  cipher matrix
# [['1', '3a', '8c', '21'], ['3e', 'b0', 'e2', '33'], ['8e', '4', '3d', 'b8'], ['a7', 'bc', '4d', '1c']]  key whitening inverse
# [['00', '3c', '6e', '47'], ['1f', '4e', '22', '74'], ['0e', '08', '1b', '31'], ['54', '59', '0b', '1a']]  I_sub bytes round: 0
# [['54', '4f', '4e', '20'], ['77', '6e', '69', '54'], ['6f', '65', '6e', '77'], ['20', '20', '65', '6f']]  decrypted round: 0
# ['T', 'w', 'o', ' ', 'O', 'n', 'e', ' ', 'N', 'i', 'n', 'e', ' ', 'T', 'w', 'o']

# %%
def pad(text):
    pad_len = 16 - (len(text) % 16)
    pad_string = "0" * pad_len
    return text + pad_string
def fix_size(text):
    if len(text)%16 == 0:
        return [text[i:i+16] for i in range(0, len(text), 16)]
    else:
        text = pad(text)
        return [text[i:i+16] for i in range(0, len(text), 16)]

# %%
############################## user inputs implemented ############################

text = input("Enter a plain text to be incrypted: ")
user_key = input("Enter a 128 bit key: ")
key = generate_Key(user_key)
print("key being used: ",key)
round_keys = gererate_round_keys(key)
for i in range(len(round_keys)):
    print("round key for round : ",i,round_keys[i])
text = fix_size(text)
all_cipher_texts = []
for i in range(len(text)):
    cipher_text = encrypt(text[i],round_keys)
    all_cipher_texts.append(cipher_text)
for i in range(len(all_cipher_texts)):
    print(all_cipher_texts[i]," ",i)
all_decipher_texts = []
for i in range(len(text)):
    decipher_text = decrypt(all_cipher_texts[i],round_keys)
    all_decipher_texts.append(decipher_text)
for i in range(len(all_decipher_texts)):
    print(all_decipher_texts[i]," ",i)
ch=[]
for i in range(len(all_decipher_texts)):
    for j in range(len(all_decipher_texts[i])):
        ch.append(chr(int(all_decipher_texts[i][j],16)))
strng=""
for i in ch:
    strng +=i
print(string)
# Out:
# Enter a plain text to be incrypted: random text to see if this works correctly
# Enter a 128 bit key: hope this key ok
# key being used:  hope this key ok
# round key for round :  0 ['68', '6f', '70', '65', '20', '74', '68', '69', '73', '20', '6b', '65', '79', '20', '6f', '6b']
# round key for round :  1 ['de', 'c7', 'f', 'd3', 'fe', 'b3', '67', 'ba', '8d', '93', 'c', 'df', 'f4', 'b3', '63', 'b4']
# round key for round :  2 ['b1', '3c', '82', '6c', '4f', '8f', 'e5', 'd6', 'c2', '1c', 'e9', '9', '36', 'af', '8a', 'bd']
# round key for round :  3 ['cc', '42', 'f8', '69', '83', 'cd', '1d', 'bf', '41', 'd1', 'f4', 'b6', '77', '7e', '7e', 'b']
# round key for round :  4 ['37', 'b1', 'd3', '9c', 'b4', '7c', 'ce', '23', 'f5', 'ad', '3a', '95', '82', 'd3', '44', '9e']
# round key for round :  5 ['41', 'aa', 'd8', '8f', 'f5', 'd6', '16', 'ac', '0', '7b', '2c', '39', '82', 'a8', '68', 'a7']
# round key for round :  6 ['a3', 'ef', '84', '9c', '56', '39', '92', '30', '56', '42', 'be', '9', 'd4', 'ea', 'd6', 'ae']
# round key for round :  7 ['64', '19', '60', 'd4', '32', '20', 'f2', 'e4', '64', '62', '4c', 'ed', 'b0', '88', '9a', '43']
# round key for round :  8 ['20', 'a1', '7a', '33', '12', '81', '88', 'd7', '76', 'e3', 'c4', '3a', 'c6', '6b', '5e', '79']
# [['a0', '71', '68', '6d'], ['49', '8c', '92', '0c'], ['d8', '39', '94', 'cd'], ['95', '86', 'a2', 'f0']]  sub bytes round:  5
# [['a0', '71', '68', '6d'], ['8c', '92', '0c', '49'], ['94', 'cd', 'd8', '39'], ['f0', '95', '86', 'a2']]  shift rows round:  5
# [['b0', '17', '9a', '9a'], ['f4', '97', '85', '16'], ['14', 'c6', '5e', 'ab'], ['18', 'fd', '7b', '98']]  mix cols round:  5
# [['f1', 'e2', '9a', '18'], ['5e', '41', 'fe', 'be'], ['cc', 'd0', '72', 'c3'], ['97', '51', '42', '3f']]  encrpted round:  5
# [['a1', '98', 'b8', 'ad'], ['58', '83', 'bb', 'ae'], ['4b', '70', '40', '2e'], ['88', 'd1', '2c', '75']]  sub bytes round:  6
# [['a1', '98', 'b8', 'ad'], ['83', 'bb', 'ae', '58'], ['40', '2e', '4b', '70'], ['75', '88', 'd1', '2c']]  shift rows round:  6
# [['f2', '5b', '18', 'f5'], ['9', 'f', 'f3', 'a1'], ['3d', 'fc', 'e8', '61'], ['d1', '2d', '8f', '9c']]  mix cols round:  6
# [['51', 'd', '4e', '21'], ['e6', '36', 'b1', '4b'], ['b9', '6e', '56', 'b7'], ['4d', '1d', '86', '32']]  encrpted round:  6
# [['d1', 'd7', '2f', 'fd'], ['8e', '05', 'c8', 'b3'], ['56', '9f', 'b1', 'a9'], ['e3', 'a4', '44', '23']]  sub bytes round:  7
# [['d1', 'd7', '2f', 'fd'], ['05', 'c8', 'b3', '8e'], ['b1', 'a9', '56', '9f'], ['23', 'e3', 'a4', '44']]  shift rows round:  7
# [['24', 'bc', '62', 'b3'], ['30', '5f', 'c', '4'], ['c8', '68', 'c7', '9a'], ['9a', 'de', 'c7', '85']]  mix cols round:  7
# [['40', '8e', '6', '3'], ['29', '7f', '6e', '8c'], ['a8', '9a', '8b', '0'], ['4e', '3a', '2a', 'c6']]  encrpted round:  7
# [['09', '19', '6f', '7b'], ['a5', 'd2', '9f', '64'], ['c2', 'b8', '3d', '63'], ['2f', '80', 'e5', 'b4']]  sub bytes round:  8
# [['09', '19', '6f', '7b'], ['d2', '9f', '64', 'a5'], ['3d', '63', 'c2', 'b8'], ['b4', '2f', '80', 'e5']]  shift rows round:  8
# [['f6', 'c4', '30', '5f'], ['45', 'b6', '7a', '1c'], ['66', '31', 'f', '81'], ['87', '89', 'c', '41']]  mix cols round:  8
# [['d6', 'd6', '46', '99'], ['e4', '37', '99', '77'], ['1c', 'b9', 'cb', 'df'], ['b4', '5e', '36', '38']]  encrpted round:  8
# [['f6', 'f6', '5a', 'ee'], ['69', '9a', 'ee', 'f5'], ['9c', '56', '1f', '9e'], ['8d', '58', '05', '07']]  sub bytes round:  9
# [['f6', 'f6', '5a', 'ee'], ['9a', 'ee', 'f5', '69'], ['1f', '9e', '9c', '56'], ['07', '8d', '58', '05']]  shift rows round:  9
# [['5a', 'cd', '74', '2f'], ['ff', '5', '4c', 'c3'], ['5b', 'b3', '64', '24'], ['8a', '70', '37', '1c']]  mix cols round:  9
# [['90', '23', 'f5', 'a2'], ['3', 'ff', 'ab', '5c'], ['96', '50', '83', 'e9'], ['cc', '74', '8e', '65']]  encrpted round:  9
# [['9e', '8e', '6e', '54'], ['f2', 'fe', '4d', '8c'], ['5d', 'eb', 'e5', 'f8'], ['44', '12', 'a1', '39']]  encrypted round: 10
# ['8c', '1b', 'd8', '7f', 'bc', '92', 'd8', '8e', 'a8', 'c4', 'fd', '84', 'b3', '98', 'c3', '6c']   0
# ['7d', '3e', 'd7', 'bb', '3', '4e', '6f', 'be', '59', '18', '8b', 'e5', '2f', '50', 'c', '4f']   1
# ['9e', 'f2', '5d', '44', '8e', 'fe', 'eb', '12', '6e', '4d', 'e5', 'a1', '54', '8c', 'f8', '39']   2
# [['8c', 'bc', 'a8', 'b3'], ['1b', '92', 'c4', '98'], ['d8', 'd8', 'fd', 'c3'], ['7f', '8e', '84', '6c']]  cipher matrix
# [['72', '14', '20', 'dd'], ['ff', 'e', 'c3', '6f'], ['69', '2d', '88', '68'], ['76', 'd7', 'b7', '4c']]  key whitening inverse
# [['72', '14', '20', 'dd'], ['6f', 'ff', 'e', 'c3'], ['88', '68', '69', '2d'], ['d7', 'b7', '4c', '76']]  I_shift rows round: 9
# [['1e', '9b', '54', 'c9'], ['06', '7d', 'd7', '33'], ['97', 'f7', 'e4', 'fa'], ['0d', '20', '5d', '0f']]  I_sub bytes round: 9
# [['5a', 'cd', '74', '2f'], ['ff', '5', '4c', 'c3'], ['5b', 'b3', '64', '24'], ['8a', '70', '37', '1c']]  decrpted round:  9
# [['f6', 'f6', '5a', 'ee'], ['9a', 'ee', 'f5', '69'], ['1f', '9e', '9c', '56'], ['7', '8d', '58', '5']]  I_mix cols round:  9
# [['f6', 'f6', '5a', 'ee'], ['69', '9a', 'ee', 'f5'], ['9c', '56', '1f', '9e'], ['8d', '58', '5', '7']]  I_shift rows round: 8
# [['d6', 'd6', '46', '99'], ['e4', '37', '99', '77'], ['1c', 'b9', 'cb', 'df'], ['b4', '5e', '36', '38']]  I_sub bytes round: 8
# [['f6', 'c4', '30', '5f'], ['45', 'b6', '7a', '1c'], ['66', '31', 'f', '81'], ['87', '89', 'c', '41']]  decrpted round:  8
# [['9', '19', '6f', '7b'], ['d2', '9f', '64', 'a5'], ['3d', '63', 'c2', 'b8'], ['b4', '2f', '80', 'e5']]  I_mix cols round:  8
# [['9', '19', '6f', '7b'], ['a5', 'd2', '9f', '64'], ['c2', 'b8', '3d', '63'], ['2f', '80', 'e5', 'b4']]  I_shift rows round: 7
# [['40', '8e', '06', '03'], ['29', '7f', '6e', '8c'], ['a8', '9a', '8b', '00'], ['4e', '3a', '2a', 'c6']]  I_sub bytes round: 7
# [['24', 'bc', '62', 'b3'], ['30', '5f', 'c', '4'], ['c8', '68', 'c7', '9a'], ['9a', 'de', 'c7', '85']]  decrpted round:  7
# [['d1', 'd7', '2f', 'fd'], ['5', 'c8', 'b3', '8e'], ['b1', 'a9', '56', '9f'], ['23', 'e3', 'a4', '44']]  I_mix cols round:  7
# [['d1', 'd7', '2f', 'fd'], ['8e', '5', 'c8', 'b3'], ['56', '9f', 'b1', 'a9'], ['e3', 'a4', '44', '23']]  I_shift rows round: 6
# [['51', '0d', '4e', '21'], ['e6', '36', 'b1', '4b'], ['b9', '6e', '56', 'b7'], ['4d', '1d', '86', '32']]  I_sub bytes round: 6
# [['f2', '5b', '18', 'f5'], ['9', 'f', 'f3', 'a1'], ['3d', 'fc', 'e8', '61'], ['d1', '2d', '8f', '9c']]  decrpted round:  6
# [['a1', '98', 'b8', 'ad'], ['83', 'bb', 'ae', '58'], ['40', '2e', '4b', '70'], ['75', '88', 'd1', '2c']]  I_mix cols round:  6
# [['a1', '98', 'b8', 'ad'], ['58', '83', 'bb', 'ae'], ['4b', '70', '40', '2e'], ['88', 'd1', '2c', '75']]  I_shift rows round: 5
# [['f1', 'e2', '9a', '18'], ['5e', '41', 'fe', 'be'], ['cc', 'd0', '72', 'c3'], ['97', '51', '42', '3f']]  I_sub bytes round: 5
# [['b0', '17', '9a', '9a'], ['f4', '97', '85', '16'], ['14', 'c6', '5e', 'ab'], ['18', 'fd', '7b', '98']]  decrpted round:  5
# [['a0', '71', '68', '6d'], ['8c', '92', 'c', '49'], ['94', 'cd', 'd8', '39'], ['f0', '95', '86', 'a2']]  I_mix cols round:  5
# [['a0', '71', '68', '6d'], ['49', '8c', '92', 'c'], ['d8', '39', '94', 'cd'], ['95', '86', 'a2', 'f0']]  I_shift rows round: 4
# [['47', '2c', 'f7', 'b3'], ['a4', 'f0', '74', '81'], ['2d', '5b', 'e7', '80'], ['ad', 'dc', '1a', '17']]  I_sub bytes round: 4
# [['70', '98', '2', '31'], ['15', '8c', 'd9', '52'], ['fe', '95', 'dd', 'c4'], ['31', 'ff', '8f', '89']]  decrpted round:  4
# [['39', '27', '53', '4b'], ['c5', 'ca', '3f', '61'], ['f8', 'd6', '85', 'e2'], ['ae', '45', '60', 'e6']]  I_mix cols round:  4
# [['39', '27', '53', '4b'], ['61', 'c5', 'ca', '3f'], ['85', 'e2', 'f8', 'd6'], ['45', '60', 'e6', 'ae']]  I_shift rows round: 3
# [['5b', '3d', '50', 'cc'], ['d8', '07', '10', '25'], ['67', '3b', 'e1', '4a'], ['68', '90', 'f5', 'be']]  I_sub bytes round: 3
# [['97', 'be', '11', 'bb'], ['9a', 'ca', 'c1', '5b'], ['9f', '26', '15', '34'], ['1', '2f', '43', 'b5']]  decrpted round:  3
# [['ca', 'b8', '60', '2e'], ['ad', '8', '96', '54'], ['ff', 'da', '73', '63'], ['b', '17', '3', '78']]  I_mix cols round:  3
# [['ca', 'b8', '60', '2e'], ['54', 'ad', '8', '96'], ['73', '63', 'ff', 'da'], ['17', '3', '78', 'b']]  I_shift rows round: 2
# [['10', '9a', '90', 'c3'], ['fd', '18', 'bf', '35'], ['8f', '00', '7d', '7a'], ['87', 'd5', 'c1', '9e']]  I_sub bytes round: 2
# [['a1', 'd5', '52', 'f5'], ['c1', '97', 'a3', '9a'], ['d', 'e5', '94', 'f0'], ['eb', '3', 'c8', '23']]  decrpted round:  2
# [['3d', '62', '2c', '14'], ['30', 'e6', 'c8', 'b7'], ['86', '1', 'ab', '72'], ['d', '21', 'e2', '6d']]  I_mix cols round:  2
# [['3d', '62', '2c', '14'], ['b7', '30', 'e6', 'c8'], ['ab', '72', '86', '1'], ['21', 'e2', '6d', 'd']]  I_shift rows round: 1
# [['8b', 'ab', '42', '9b'], ['20', '08', 'f5', 'b1'], ['0e', '1e', 'dc', '09'], ['7b', '3b', 'b3', 'f3']]  I_sub bytes round: 1
# [['55', '55', 'cf', '6f'], ['e7', 'bb', '66', '2'], ['1', '79', 'd0', '6a'], ['a8', '81', '6c', '47']]  decrpted round:  1
# [['a2', '84', '47', 'd7'], ['d4', '6a', '84', 'ab'], ['c0', '84', '72', '52'], ['ad', '7c', 'a4', '6e']]  I_mix cols round:  1
# [['a2', '84', '47', 'd7'], ['ab', 'd4', '6a', '84'], ['72', '52', 'c0', '84'], ['7c', 'a4', '6e', 'ad']]  I_shift rows round: 0
# [['1a', '4f', '16', '0d'], ['0e', '19', '58', '4f'], ['1e', '48', '1f', '4f'], ['01', '1d', '45', '18']]  I_sub bytes round: 0
# [['72', '6f', '65', '74'], ['61', '6d', '78', '6f'], ['6e', '20', '74', '20'], ['64', '74', '20', '73']]  decrypted round: 0
# [['7d', '3', '59', '2f'], ['3e', '4e', '18', '50'], ['d7', '6f', '8b', 'c'], ['bb', 'be', 'e5', '4f']]  cipher matrix
# [['83', 'ab', 'd1', '41'], ['da', 'd2', '1f', 'a7'], ['66', '9a', 'fe', 'a7'], ['b2', 'e7', 'd6', '6f']]  key whitening inverse
# [['83', 'ab', 'd1', '41'], ['a7', 'da', 'd2', '1f'], ['fe', 'a7', '66', '9a'], ['e7', 'd6', '6f', 'b2']]  I_shift rows round: 9
# [['41', '0e', '51', 'f8'], ['89', '7a', '7f', 'cb'], ['0c', '89', 'd3', '37'], ['b0', '4a', '06', '3e']]  I_sub bytes round: 9
# [['5', '58', '71', '1e'], ['70', '2', 'e4', '3b'], ['c0', 'cd', '53', 'e9'], ['37', '1a', '6c', '2d']]  decrpted round:  9
# [['28', '7', '45', 'd'], ['f2', '6e', 'a', '74'], ['f2', '93', '28', '23'], ['aa', '77', 'cd', 'bb']]  I_mix cols round:  9
# [['28', '7', '45', 'd'], ['74', 'f2', '6e', 'a'], ['28', '23', 'f2', '93'], ['77', 'cd', 'bb', 'aa']]  I_shift rows round: 8
# [['ee', '38', '68', 'f3'], ['ca', '04', '45', 'a3'], ['ee', '32', '04', '22'], ['02', '80', 'fe', '62']]  I_sub bytes round: 8
# [['ce', '2a', '1e', '35'], ['6b', '85', 'a6', 'c8'], ['94', 'ba', 'c0', '7c'], ['31', '57', 'c4', '1b']]  decrpted round:  8
# [['ec', '7d', 'b', 'cd'], ['fd', 'fa', 'd2', 'fc'], ['b6', '69', 'b6', 'ab'], ['a7', 'ac', 'd3', '0']]  I_mix cols round:  8
# [['ec', '7d', 'b', 'cd'], ['fc', 'fd', 'fa', 'd2'], ['b6', 'ab', 'b6', '69'], ['ac', 'd3', '0', 'a7']]  I_shift rows round: 7
# [['83', '13', '9e', '80'], ['55', '21', '14', '7f'], ['79', '0e', '79', 'e4'], ['aa', 'a9', '52', '89']]  I_sub bytes round: 7
# [['e7', '21', 'fa', '30'], ['4c', '1', '76', 'f7'], ['19', 'fc', '35', '7e'], ['7e', '4d', 'bf', 'ca']]  decrpted round:  7
# [['89', '4d', 'de', '40'], ['d8', 'be', 'cf', 'cc'], ['f4', 'a9', '1d', 'e8'], ['69', 'cb', 'a', '17']]  I_mix cols round:  7
# [['89', '4d', 'de', '40'], ['cc', 'd8', 'be', 'cf'], ['1d', 'e8', 'f4', 'a9'], ['cb', 'a', '17', '69']]  I_shift rows round: 6
# [['f2', '65', '9c', '72'], ['27', '2d', '5a', '5f'], ['de', 'c8', 'ba', 'b7'], ['59', 'a3', '87', 'e4']]  I_sub bytes round: 6
# [['51', '33', 'ca', 'a6'], ['c8', '14', '18', 'b5'], ['5a', '5a', '4', '61'], ['c5', '93', '8e', '4a']]  decrpted round:  6
# [['62', '1d', 'ce', '52'], ['f5', '7d', 'e0', '34'], ['65', 'b3', 'b0', 'e5'], ['f4', '3d', 'c6', 'bb']]  I_mix cols round:  6
# [['62', '1d', 'ce', '52'], ['34', 'f5', '7d', 'e0'], ['b0', 'e5', '65', 'b3'], ['3d', 'c6', 'bb', 'f4']]  I_shift rows round: 5
# [['ab', 'de', 'ec', '48'], ['28', '77', '13', 'a0'], ['fc', '2a', 'bc', '4b'], ['8b', 'c7', 'fe', 'ba']]  I_sub bytes round: 5
# [['ea', '2b', 'ec', 'ca'], ['82', 'a1', '68', '8'], ['24', '3c', '90', '23'], ['4', '6b', 'c7', '1d']]  decrpted round:  5
# [['11', '17', '5', '81'], ['c5', 'ea', '18', '57'], ['4f', 'a1', 'c4', '8b'], ['d3', '81', 'a', 'a1']]  I_mix cols round:  5
# [['11', '17', '5', '81'], ['57', 'c5', 'ea', '18'], ['c4', '8b', '4f', 'a1'], ['81', 'a', 'a1', 'd3']]  I_shift rows round: 4
# [['e3', '87', '36', '91'], ['da', '07', 'bb', '34'], ['88', 'ce', '92', 'f1'], ['91', 'a3', 'f1', 'a9']]  I_sub bytes round: 4
# [['d4', '33', 'c3', '13'], ['6b', '7b', '16', 'e7'], ['5b', '0', 'a8', 'b5'], ['d', '80', '64', '37']]  decrpted round:  4
# [['5b', 'bd', '14', 'a5'], ['68', '9e', '73', 'c5'], ['1d', '5', '4d', 'ef'], ['c7', 'ee', '33', 'f9']]  I_mix cols round:  4
# [['5b', 'bd', '14', 'a5'], ['c5', '68', '9e', '73'], ['4d', 'ef', '1d', '5'], ['ee', '33', 'f9', 'c7']]  I_shift rows round: 3
# [['57', 'cd', '9b', '29'], ['07', 'f7', 'df', '8f'], ['65', '61', 'de', '36'], ['99', '66', '69', '31']]  I_sub bytes round: 3
# [['9b', '4e', 'da', '5e'], ['45', '3a', 'e', 'f1'], ['9d', '7c', '2a', '48'], ['f0', 'd9', 'df', '3a']]  decrpted round:  3
# [['78', '6d', 'b6', '2c'], ['50', '14', '1d', 'f6'], ['3', 'e6', '4', '9b'], ['98', '4e', '8e', '9c']]  I_mix cols round:  3
# [['78', '6d', 'b6', '2c'], ['f6', '50', '14', '1d'], ['4', '9b', '3', 'e6'], ['4e', '8e', '9c', '98']]  I_shift rows round: 2
# [['c1', 'b3', '79', '42'], ['d6', '6c', '9b', 'de'], ['30', 'e8', 'd5', 'f5'], ['b6', 'e6', '1c', 'e2']]  I_sub bytes round: 2
# [['70', 'fc', 'bb', '74'], ['ea', 'e3', '87', '71'], ['b2', 'd', '3c', '7f'], ['da', '30', '15', '5f']]  decrpted round:  2
# [['59', '2', '54', '44'], ['b9', '6c', '29', 'c3'], ['64', 'b7', 'f9', '5'], ['76', 'fb', '91', 'a7']]  I_mix cols round:  2
# [['59', '2', '54', '44'], ['c3', 'b9', '6c', '29'], ['f9', '5', '64', 'b7'], ['fb', '91', 'a7', '76']]  I_shift rows round: 1
# [['15', '6a', 'fd', '86'], ['33', 'db', 'b8', '4c'], ['69', '36', '8c', '20'], ['63', 'ac', '89', '0f']]  I_sub bytes round: 1
# [['cb', '94', '70', '72'], ['f4', '68', '2b', 'ff'], ['66', '51', '80', '43'], ['b0', '16', '56', 'bb']]  decrpted round:  1
# [['d7', '5a', 'a2', '47'], ['20', 'ed', '0', '67'], ['b3', 'f2', '53', '9c'], ['ad', 'fe', '7c', 'c9']]  I_mix cols round:  1
# [['d7', '5a', 'a2', '47'], ['67', '20', 'ed', '0'], ['53', '9c', 'b3', 'f2'], ['fe', '7c', 'c9', 'ad']]  I_shift rows round: 0
# [['0d', '46', '1a', '16'], ['0a', '54', '53', '52'], ['50', '1c', '4b', '04'], ['0c', '01', '12', '18']]  I_sub bytes round: 0
# [['65', '66', '69', '6f'], ['65', '20', '73', '72'], ['20', '74', '20', '6b'], ['69', '68', '77', '73']]  decrypted round: 0
# [['9e', '8e', '6e', '54'], ['f2', 'fe', '4d', '8c'], ['5d', 'eb', 'e5', 'f8'], ['44', '12', 'a1', '39']]  cipher matrix
# [['60', '26', 'e6', '3a'], ['16', '62', '4a', '7b'], ['ec', '1e', '90', '53'], ['4d', '4b', '92', '19']]  key whitening inverse
# [['60', '26', 'e6', '3a'], ['7b', '16', '62', '4a'], ['90', '53', 'ec', '1e'], ['4b', '92', '19', '4d']]  I_shift rows round: 9
# [['90', '23', 'f5', 'a2'], ['03', 'ff', 'ab', '5c'], ['96', '50', '83', 'e9'], ['cc', '74', '8e', '65']]  I_sub bytes round: 9
# [['d4', '75', 'd5', '44'], ['fa', '87', '30', 'ac'], ['5a', '14', '3', '37'], ['4b', '24', 'e4', '76']]  decrpted round:  9
# [['5a', '9d', '63', 'ce'], ['8f', '88', '39', '52'], ['aa', '63', 'b1', 'f4'], ['40', 'b4', 'e9', 'c1']]  I_mix cols round:  9
# [['5a', '9d', '63', 'ce'], ['52', '8f', '88', '39'], ['b1', 'f4', 'aa', '63'], ['b4', 'e9', 'c1', '40']]  I_shift rows round: 8
# [['46', '75', '00', 'ec'], ['48', '73', '97', '5b'], ['56', 'ba', '62', '00'], ['c6', 'eb', 'dd', '72']]  I_sub bytes round: 8
# [['66', '67', '76', '2a'], ['e9', 'f2', '74', '30'], ['2c', '32', 'a6', '5e'], ['f5', '3c', 'e7', 'b']]  decrpted round:  8
# [['80', '36', '72', 'd4'], ['d8', '53', 'dc', '1'], ['66', '4e', '24', '3e'], ['68', 'b0', 'c9', 'a4']]  I_mix cols round:  8
# [['80', '36', '72', 'd4'], ['1', 'd8', '53', 'dc'], ['24', '3e', '66', '4e'], ['b0', 'c9', 'a4', '68']]  I_shift rows round: 7
# [['3a', '24', '1e', '19'], ['09', '2d', '50', '93'], ['a6', 'd1', 'd3', 'b6'], ['fc', '12', '1d', 'f7']]  I_sub bytes round: 7
# [['5e', '16', '7a', 'a9'], ['10', 'd', '32', '1b'], ['c6', '23', '9f', '2c'], ['28', 'f6', 'f0', 'b4']]  decrpted round:  7
# [['43', '10', '57', '95'], ['90', '74', '52', '9e'], ['80', 'a2', 'fc', '44'], ['f3', '8', 'de', '65']]  I_mix cols round:  7
# [['43', '10', '57', '95'], ['9e', '90', '74', '52'], ['fc', '44', '80', 'a2'], ['8', 'de', '65', 'f3']]  I_shift rows round: 6
# [['64', '7c', 'da', 'ad'], ['df', '96', 'ca', '48'], ['55', '86', '3a', '1a'], ['bf', '9c', 'bc', '7e']]  I_sub bytes round: 6
# [['c7', '2a', '8c', '79'], ['30', 'af', '88', 'a2'], ['d1', '14', '84', 'cc'], ['23', 'ac', 'b5', 'd0']]  decrpted round:  6
# [['47', 'd', '22', '93'], ['88', '0', 'e2', '8'], ['5b', '49', '40', 'b3'], ['91', '79', 'b5', 'ef']]  I_mix cols round:  6
# [['47', 'd', '22', '93'], ['8', '88', '0', 'e2'], ['40', 'b3', '5b', '49'], ['79', 'b5', 'ef', '91']]  I_shift rows round: 5
# [['16', 'f3', '94', '22'], ['bf', '97', '52', '3b'], ['72', '4b', '57', 'a4'], ['af', 'd2', '61', 'ac']]  I_sub bytes round: 5
# [['57', '6', '94', 'a0'], ['15', '41', '29', '93'], ['aa', '5d', '7b', 'cc'], ['20', '7e', '58', 'b']]  decrpted round:  5
# [['d8', '96', '66', '78'], ['76', 'ec', '50', '6e'], ['ae', '5', 'ae', 'e7'], ['c8', '1b', '6', '5']]  I_mix cols round:  5
# [['d8', '96', '66', '78'], ['6e', '76', 'ec', '50'], ['ae', 'e7', 'ae', '5'], ['1b', '6', '5', 'c8']]  I_shift rows round: 4
# [['2d', '35', 'd3', 'c1'], ['45', '0f', '83', '6c'], ['be', 'b0', 'be', '36'], ['44', 'a5', '36', 'b1']]  I_sub bytes round: 4
# [['1a', '81', '26', '43'], ['f4', '73', '2e', 'bf'], ['6d', '7e', '84', '72'], ['d8', '86', 'a3', '2f']]  decrpted round:  4
# [['af', 'f5', 'c4', 'ba'], ['d8', 'ca', '2f', '96'], ['6e', '1e', '38', 'd2'], ['42', '2b', 'fc', '5f']]  I_mix cols round:  4
# [['af', 'f5', 'c4', 'ba'], ['96', 'd8', 'ca', '2f'], ['38', 'd2', '6e', '1e'], ['2b', 'fc', '5f', '42']]  I_shift rows round: 3
# [['1b', '77', '88', 'c0'], ['35', '2d', '10', '4e'], ['76', '7f', '45', 'e9'], ['0b', '55', '84', 'f6']]  I_sub bytes round: 3
# [['d7', 'f4', 'c9', 'b7'], ['77', 'e0', 'c1', '30'], ['8e', '62', 'b1', '97'], ['62', 'ea', '32', 'fd']]  decrpted round:  3
# [['e9', 'a2', '9d', 'e6'], ['d0', 'c7', '7f', 'b8'], ['28', '17', 'e8', '7'], ['5d', 'ee', '81', 'b4']]  I_mix cols round:  3
# [['e9', 'a2', '9d', 'e6'], ['b8', 'd0', 'c7', '7f'], ['e8', '7', '28', '17'], ['ee', '81', 'b4', '5d']]  I_shift rows round: 2
# [['eb', '1a', '75', 'f5'], ['9a', '60', '31', '6b'], ['c8', '38', 'ee', '87'], ['99', '91', 'c6', '8d']]  I_sub bytes round: 2
# [['5a', '55', 'b7', 'c3'], ['a6', 'ef', '2d', 'c4'], ['4a', 'dd', '7', 'd'], ['f5', '47', 'cf', '30']]  decrpted round:  2
# [['94', '17', '9a', '29'], ['5f', '26', '28', '41'], ['2', 'df', '8e', '93'], ['8a', 'ce', '6e', 'c1']]  I_mix cols round:  2
# [['94', '17', '9a', '29'], ['41', '5f', '26', '28'], ['8e', '93', '2', 'df'], ['ce', '6e', 'c1', '8a']]  I_shift rows round: 1
# [['e7', '87', '37', '4c'], ['f8', '84', '23', 'ee'], ['e6', '22', '6a', 'ef'], ['ec', '45', 'dd', 'cf']]  I_sub bytes round: 1
# [['39', '79', 'ba', 'b8'], ['3f', '37', 'b0', '5d'], ['e9', '45', '66', '8c'], ['3f', 'ff', '2', '7b']]  decrpted round:  1
# [['52', '0', 'c0', '3b'], ['82', 'cb', 'ca', 'fe'], ['39', 'cf', 'c0', '2b'], ['39', 'f0', 'a4', 'fc']]  I_mix cols round:  1
# [['52', '0', 'c0', '3b'], ['fe', '82', 'cb', 'ca'], ['c0', '2b', '39', 'cf'], ['f0', 'a4', 'fc', '39']]  I_shift rows round: 0
# [['48', '52', '1f', '49'], ['0c', '11', '59', '10'], ['1f', '0b', '5b', '5f'], ['17', '1d', '55', '5b']]  I_sub bytes round: 0
# [['20', '72', '6c', '30'], ['63', '65', '79', '30'], ['6f', '63', '30', '30'], ['72', '74', '30', '30']]  decrypted round: 0
# ['72', '61', '6e', '64', '6f', '6d', '20', '74', '65', '78', '74', '20', '74', '6f', '20', '73']   0
# ['65', '65', '20', '69', '66', '20', '74', '68', '69', '73', '20', '77', '6f', '72', '6b', '73']   1
# ['20', '63', '6f', '72', '72', '65', '63', '74', '6c', '79', '30', '30', '30', '30', '30', '30']   2
# random text to see if this works correctly000000
